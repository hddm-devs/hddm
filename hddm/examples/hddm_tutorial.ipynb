# %% [markdown]
# # HDDM tutorial. Welcome, nerds!

# %% [raw]
# Import the modules we are going to use. Pandas for the dataframe and matplotlib for plotting.

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.figsize(12,8)

# %%
import hddm
print hddm.__version__

import kabuki
print kabuki.__version__
# Out:
# 0.4.1
# 0.4.1

# %% [markdown]
# ## Loading data

# %%
# !head PD_PS.csv
# Out:
# subj_idx,stim,rt,response,prer1,prer2,theta,cue2,dbs,conf,dbs_effect,dbs_effect_inv,dbs_inv
# 0,LL,1.21,1.0,0.0,1.0,0.656275122261,1.0,1,HC,1,-1,0
# 0,WL,1.63,1.0,0.0,1.0,-0.327888671662,0.0,1,LC,1,-1,0
# 0,WW,1.03,1.0,0.0,1.0,-0.480284512399,0.0,1,HC,1,-1,0
# 0,WL,2.77,1.0,0.0,1.0,1.92742734524,1.0,1,LC,1,-1,0
# 0,WW,1.14,0.0,0.0,1.0,-0.21323572606,1.0,1,HC,1,-1,0
# 0,WL,1.15,1.0,0.0,1.0,-0.436203659401,0.0,1,LC,1,-1,0
# 0,LL,2.0,1.0,0.0,1.0,-0.274478914394,1.0,1,HC,1,-1,0
# 0,WL,1.04,0.0,0.0,1.0,0.666957073714,1.0,1,LC,1,-1,0
# 0,WW,0.857,1.0,0.0,1.0,0.118616899098,0.0,1,HC,1,-1,0

# %%
data = pd.DataFrame(hddm.load_csv('PD_PS.csv'))
del data['conf']
data = hddm.utils.flip_errors(data)

# %%
data.head(10)
# Out:
#    subj_idx stim     rt  response  prer1  prer2     theta  cue2  dbs  dbs_effect  dbs_effect_inv  dbs_inv
# 0         0   LL  1.210         1      0      1  0.656275     1    1           1              -1        0
# 1         0   WL  1.630         1      0      1 -0.327889     0    1           1              -1        0
# 2         0   WW  1.030         1      0      1 -0.480285     0    1           1              -1        0
# 3         0   WL  2.770         1      0      1  1.927427     1    1           1              -1        0
# 4         0   WW -1.140         0      0      1 -0.213236     1    1           1              -1        0
# 5         0   WL  1.150         1      0      1 -0.436204     0    1           1              -1        0
# 6         0   LL  2.000         1      0      1 -0.274479     1    1           1              -1        0
# 7         0   WL -1.040         0      0      1  0.666957     1    1           1              -1        0
# 8         0   WW  0.857         1      0      1  0.118617     0    1           1              -1        0
# 9         0   WL -1.500         0      0      1  0.823626     1    1           1              -1        0

# %% [raw]
# To make things a little quicker and interactive, lets discard some of the subjects.

# %%
subj_idx = data.subj_idx.unique()
data = data[data.subj_idx.isin(subj_idx[:8])]
data.subj_idx.unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7], dtype=int64)

# %% [raw]
# Lets look at the RT distributions

# %%
fig = plt.figure()
ax = fig.add_subplot(111, xlabel='RT', ylabel='count', title='RT distributions')
for i, subj_data in data.groupby('subj_idx'):
    ax.hist(subj_data.rt, bins=20, histtype='step')

# %% [markdown]
# ## The Drift-Diffusion model

# %% [markdown]
# ![](http://ski.clps.brown.edu/hddm_docs/_images/DDM_drifts_w_labels.svg)

# %% [raw]
# Lets create a simple, hierarchical model.

# %%
m = hddm.HDDM(data)

# %% [markdown]
# Here is what the graphical model representation looks like:
#
# ![](http://ski.clps.brown.edu/hddm_docs/_images/hier_model.svg)
# $$\mu_{a} \sim \mathcal{N}(0, 1)$$
# $$\mu_{z} \sim \mathcal{N}(0, 1)$$
# $$\mu_{v} \sim \mathcal{N}(0, 1)$$
# $$\mu_{ter} \sim \mathcal{N}(0, 1)$$
# $$\mu_{sv} \sim \mathcal{N}(0, 1)$$
# $$\mu_{sz} \sim \mathcal{N}(0, 1)$$
# $$\mu_{ster} \sim \mathcal{N}(0, 1)$$
#
# $$\sigma_{a} \sim \mathcal{U}(1e^{-10}, 100)$$
# $$\sigma_{z} \sim \mathcal{U}(1e^{-10}, 100)$$
# $$\sigma_{v} \sim \mathcal{U}(1e^{-10}, 100)$$
# $$\sigma_{ter} \sim \mathcal{U}(1e^{-10}, 100)$$
# $$\sigma_{sv} \sim \mathcal{U}(1e^{-10}, 100)$$
# $$\sigma_{sz} \sim \mathcal{U}(1e^{-10}, 100)$$
# $$\sigma_{ster} \sim \mathcal{U}(1e^{-10}, 100)$$
#
# $$a_{i} \sim \mathcal{N}(\mu_{a}, \sigma_{a})$$
# $$z_{i} \sim \mathcal{N}(\mu_{z}, \sigma_{z})$$
# $$v_{i} \sim \mathcal{N}(\mu_{v}, \sigma_{v})$$
# $$ter_{i} \sim \mathcal{N}(\mu_{ter}, \sigma_{ter})$$
# $$sv_{i} \sim \mathcal{N}(\mu_{sv}, \sigma_{sv})$$
# $$sz_{i} \sim \mathcal{N}(\mu_{sz}, \sigma_{sz})$$
# $$ster_{i} \sim \mathcal{N}(\mu_{ster}, \sigma_{ster})$$
#
# $$RT_{i, j} \sim wfpt(a_{i}, z_{i}, v_{i}, ter_{i}, sv_{i}, sz_{i}, ster_{i})$$

# %%
# find a good starting point
m.find_starting_values()
# start drawing 5000 samples and discarding 2000 as burn-in
m.sample(5000, burn=2000)
# Out:
# [****************100%******************]  5000 of 5000 complete

# %% [raw]
# Analyze model

# %%
m.gen_stats()
# Out:
#               mean       std      2.5q       25q       50q       75q     97.5q    mc err
# a         1.884788  0.154485  1.600214  1.791213  1.878498  1.970293  2.210027  0.003570
# a_var     0.209870  0.078265  0.112427  0.158241  0.193662  0.240952  0.403242  0.001848
# a_subj.0  2.388225  0.058939  2.260717  2.345047  2.385096  2.430441  2.506841  0.004040
# a_subj.1  2.126979  0.069324  2.014756  2.077206  2.124537  2.174642  2.274736  0.005816
# a_subj.2  1.748940  0.050970  1.650488  1.715661  1.747534  1.777846  1.860085  0.003691
# a_subj.3  2.241691  0.061749  2.121790  2.192895  2.244337  2.285855  2.362495  0.004464
# a_subj.4  1.495803  0.053771  1.402862  1.456942  1.491516  1.528551  1.620839  0.004218
# a_subj.5  1.765590  0.045867  1.687824  1.732887  1.762557  1.799858  1.857065  0.003516
# a_subj.6  1.616975  0.049147  1.519604  1.583187  1.614655  1.649832  1.705043  0.003780
# a_subj.7  1.868760  0.050017  1.775076  1.831650  1.872910  1.901670  1.967292  0.003560
# v         0.406037  0.150634  0.100638  0.320287  0.409061  0.495480  0.697146  0.002756
# v_var     0.391623  0.154181  0.213528  0.294057  0.355420  0.450884  0.763919  0.003866
# v_subj.0  0.107272  0.050461  0.009759  0.074295  0.106459  0.139509  0.208209  0.001900
# v_subj.1  0.619229  0.059875  0.502896  0.582200  0.616834  0.656435  0.745473  0.002717
# v_subj.2  0.516439  0.075216  0.362370  0.467300  0.516201  0.568033  0.665384  0.002883
# v_subj.3  0.135282  0.057203  0.020669  0.095819  0.133854  0.173416  0.249604  0.002021
# v_subj.4  0.931324  0.089866  0.753444  0.869527  0.931612  0.987076  1.101419  0.004678
# v_subj.5  0.470616  0.063964  0.354477  0.425115  0.465149  0.516417  0.601466  0.002832
# v_subj.6  0.436420  0.073735  0.287614  0.389277  0.433839  0.484882  0.583846  0.002682
# v_subj.7  0.019771  0.062534 -0.108316 -0.020480  0.021801  0.062218  0.140559  0.002719
# t         0.413410  0.032188  0.359458  0.394636  0.411970  0.430634  0.480569  0.000683
# t_var     0.199834  0.075326  0.109861  0.151874  0.184295  0.228158  0.379295  0.001869
# t_subj.0  0.403789  0.013576  0.368071  0.398377  0.404712  0.413591  0.426297  0.001051
# t_subj.1  0.394473  0.017674  0.349620  0.384580  0.394476  0.407624  0.419452  0.001500
# t_subj.2  0.382472  0.008926  0.365191  0.375585  0.382754  0.388279  0.397488  0.000683
# t_subj.3  0.480321  0.014554  0.452239  0.470989  0.481459  0.492515  0.501687  0.001209
# t_subj.4  0.343307  0.009012  0.322024  0.338074  0.344175  0.347445  0.359862  0.000787
# t_subj.5  0.352659  0.011441  0.327200  0.345629  0.354797  0.358728  0.372399  0.000960
# t_subj.6  0.417725  0.009739  0.399109  0.411290  0.419116  0.425316  0.433562  0.000827
# t_subj.7  0.556269  0.011253  0.529147  0.548754  0.556982  0.566079  0.573199  0.000954

# %%
m.plot_posteriors(plot_subjs=True)
# Out:
# Plotting a
# Plotting
#  a_var
# Plotting
#  a_subj.0
# Plotting
#  a_subj.1
# Plotting
#  a_subj.2
# Plotting
#  a_subj.3
# Plotting
#  a_subj.4
# Plotting
#  a_subj.5
# Plotting
#  a_subj.6
# Plotting
#  a_subj.7
# Plotting
#  v
# Plotting
#  v_var
# Plotting
#  v_subj.0
# Plotting
#  v_subj.1
# Plotting
#  v_subj.2
# Plotting
#  v_subj.3
# Plotting
#  v_subj.4
# Plotting
#  v_subj.5
# Plotting
#  v_subj.6
# Plotting
#  v_subj.7
# Plotting
#  t
# Plotting
#  t_var
# Plotting
#  t_subj.0
# Plotting
#  t_subj.1
# Plotting
#  t_subj.2
# Plotting
#  t_subj.3
# Plotting
#  t_subj.4
# Plotting
#  t_subj.5
# Plotting
#  t_subj.6
# Plotting
#  t_subj.7

# %%
m.plot_posterior_predictive(columns=3, figsize=(14, 10))

# %% [raw]
# Certainly there is more structure in our experiment, lets see if we can model LL, WL and WW conflicts.

# %%
m_stim = hddm.HDDM(data, depends_on={'v': 'stim'})
# v_subj(WL).6  0.590463  0.096980  0.403829  0.521783  0.588032  0.656365  0.793104  0.004397
# v_subj(WL).7  0.210713  0.088086  0.034185  0.148221  0.213619  0.276250  0.378177  0.004497
# v_subj(WW).0  0.073110  0.098084 -0.109487  0.006293  0.071267  0.142995  0.268175  0.004510
# v_subj(WW).1  0.421060  0.118400  0.195449  0.344106  0.417627  0.495042  0.645435  0.005430
# v_subj(WW).2  0.375805  0.137128  0.098665  0.282159  0.375797  0.471060  0.640111  0.007178
# v_subj(WW).3  0.000959  0.001295 -0.000167 -0.000025  0.000111  0.001977  0.003919  0.000129
# v_subj(WW).4  0.717908  0.175942  0.384986  0.601675  0.715949  0.840075  1.058032  0.007839
# v_subj(WW).5  0.183474  0.135131 -0.082704  0.089041  0.180099  0.280443  0.443680  0.006193
# v_subj(WW).6  0.168714  0.146616 -0.122551  0.068328  0.176239  0.262184  0.452692  0.007989
# v_subj(WW).7 -0.210801  0.128971 -0.448776 -0.300909 -0.211360 -0.125427  0.049466  0.007386
# t             0.410888  0.030943  0.352462  0.391585  0.410601  0.430045  0.477966  0.000708
# t_var         0.200801  0.074398  0.109293  0.152238  0.186628  0.229618  0.386867  0.002230
# t_subj.0      0.406971  0.011915  0.382423  0.400760  0.406911  0.415867  0.427392  0.000952
# t_subj.1      0.389309  0.014102  0.363031  0.379090  0.391035  0.397579  0.417720  0.001152
# t_subj.2      0.382179  0.006515  0.368172  0.377261  0.381998  0.386381  0.396098  0.000535
# t_subj.3      0.479227  0.017676  0.436329  0.470033  0.482129  0.491800  0.506647  0.001331
# t_subj.4      0.343333  0.009364  0.323703  0.337832  0.343697  0.351164  0.357995  0.000859
# t_subj.5      0.352625  0.011053  0.329618  0.344933  0.352490  0.361126  0.371436  0.000951
# t_subj.6      0.420839  0.009946  0.398239  0.413408  0.423192  0.428930  0.436724  0.000845
# t_subj.7      0.552118  0.009611  0.532992  0.547300  0.552469  0.558719  0.569261  0.000771

# %%
m_stim.plot_posteriors()
# Out:
# Plotting a
# Plotting
#  a_var
# Plotting
#  v(LL)
# Plotting
#  v(WL)
# Plotting
#  v(WW)
# Plotting
#  v_var
# Plotting
#  t
# Plotting
#  t_var

# %%
kabuki.analyze.plot_posterior_nodes(m_stim.nodes_db.node[['v(WW)', 'v(LL)', 'v(WL)']])

# %% [raw]
# Seems like WW and LL are almost the same, lets see if we can combine them.

# %%
# Add new column conf to data
data['conf'] = 'LC'
data.conf[data.stim.isin(['LL', 'WW'])] = 'HC'

# %%
m_conf = hddm.HDDM(data, depends_on={'v': 'conf'})
m_conf.find_starting_values()
m_conf.sample(5000, burn=3000)
# Out:
# [****************100%******************]  5000 of 5000 complete

# %%
m_conf.gen_stats()
# Out:
#                   mean       std      2.5q       25q       50q       75q     97.5q    mc err
# a             1.907066  0.151867  1.615777  1.812710  1.899989  1.990651  2.236887  0.003515
# a_var         0.207300  0.074567  0.114167  0.156830  0.189127  0.237836  0.412035  0.002359
# t_subj.1      0.392606  0.016217  0.357407  0.382739  0.394381  0.404594  0.417721  0.001371
# t_subj.2      0.380725  0.007712  0.363065  0.375448  0.381990  0.385381  0.393776  0.000653
# t_subj.3      0.480466  0.020285  0.431622  0.469398  0.481256  0.494797  0.520174  0.001693
# t_subj.4      0.345729  0.008443  0.325748  0.341964  0.346188  0.350736  0.358926  0.000737
# t_subj.5      0.349900  0.011298  0.325663  0.344527  0.351763  0.356409  0.370254  0.000936
# t_subj.6      0.419325  0.009815  0.394457  0.414052  0.419943  0.424485  0.439007  0.000818
# t_subj.7      0.554304  0.009247  0.530843  0.549109  0.556150  0.559519  0.572815  0.000770

# %%
m_conf.plot_posteriors()
# Out:
# Plotting a
# Plotting
#  a_var
# Plotting
#  v(HC)
# Plotting
#  v(LC)
# Plotting
#  v_var
# Plotting
#  t
# Plotting
#  t_var

# %%
kabuki.analyze.plot_posterior_nodes(m_conf.nodes_db.node[['v(HC)', 'v(LC)']])

# %% [raw]
# Lets compare the two models using DIC (lower is better).

# %%
print "Lumped model DIC: %f" % m.dic_info()['DIC']
print "Stimulus model DIC: %f" % m_stim.dic_info()['DIC']
print "Conflict model DIC: %f" % m_conf.dic_info()['DIC']
# Out:
# Lumped model DIC: 5809.044698
# Stimulus model DIC: 5718.825168
# Conflict model DIC: 5712.964223

# %% [markdown]
# ## Inter-trial variabilities

# %%
# generate new simulated data
data_sv, params = hddm.generate.gen_rand_data(params={'a': 2, 'v': 1, 't': .3, 'z': .3, 'sv': .2, 'st': 0, 'sz': 0}, size=200, subjs=8)

# %%
m_inter = hddm.HDDM(data_sv, include=['sv', 'z'])
m_inter.find_starting_values()
m_inter.sample(5000, burn=3000)
# Out:
# [****************100%******************]  5000 of 5000 complete

# %%
stats = m_inter.gen_stats()
stats[stats.index.isin(['sv', 'z'])]
# Out:
#         mean       std      2.5q       25q       50q       75q     97.5q    mc err
# sv  0.048978  0.061561  0.004568  0.011195  0.028072  0.059076  0.236260  0.005389
# z   0.304870  0.050191  0.213121  0.274183  0.301561  0.330907  0.410389  0.001447

# %%
m_inter.plot_posteriors(['sv', 'sv_var', 'z'])
# Out:
# Plotting sv
# Plotting
#  sv_var
# Plotting
#  z

# %% [raw]
# Terrible convergence for sv. It often works better when not even attempt to estimate individual subject parameters for sv and only do group mean.

# %%
m_inter_group = hddm.HDDM(data_sv, include=['sv', 'z'], group_only_nodes=['sv'])
m_inter_group.find_starting_values()
m_inter_group.sample(5000, burn=3000)
# Out:
# [****************100%******************]  5000 of 5000 complete

# %%
stats = m_inter_group.gen_stats()
stats[stats.index.isin(['sv', 'z'])]
# Out:
#         mean       std      2.5q       25q       50q       75q     97.5q    mc err
# sv  4.937688  3.028154  0.651811  2.140814  4.269789  8.266462  9.727480  0.302702
# z   0.201378  0.049003  0.127552  0.167821  0.192954  0.227471  0.314912  0.003272

# %%
m_inter_group.plot_posteriors(['sv', 'z'])
# Out:
# Plotting sv
# Plotting
#  z

# %% [markdown]
# ## Running multiple chains (in parallel). This requires the git version of hddm, not 0.4.

# %%
# define a stand-alone function that will be executed remotely
def run_model(id):
    import hddm
    import numpy
    numpy.random.seed(123)
    params = {'a': 2, 'v': 1, 't': .3, 'sv':0, 'st':0, 'sz':0, 'z':.5}
    data, _ = hddm.generate.gen_rand_data(params=params, size=300)
    m = hddm.HDDM(data)
    m.find_starting_values()
    m.sample(20000, burn=15000, dbname='db%i'%id, db='pickle')
    return m

from IPython.parallel import Client
job_queue = Client(profile='hddm')[:]
jobs = job_queue.map(run_model, range(8))
models = jobs.get()

# %%
kabuki.analyze.gelman_rubin(models)

# %% [markdown]
# ## Dealing with outliers

# %%
outlier_data, params = hddm.generate.gen_rand_data(size=200, n_fast_outliers=10)
params

# %%
m_no_outlier = hddm.HDDM(outlier_data)
m_no_outlier.sample(10000, burn=5000)

# %%
m_no_outlier.plot_posterior_predictive(columns=1)

# %%
m_no_outlier.plot_posterior_quantiles(columns=1)

# %%
m_outlier = hddm.HDDM(outlier_data, p_outlier=.05)
m_outlier.sample(10000, burn=5000)

# %%
m_outlier.gen_stats()

# %%
m_outlier.plot_posterior_predictive(columns=1)

# %%
m_outlier.plot_posterior_quantiles(columns=1)

# %% [markdown]
# ## Fitting regression models

# %%
data = pd.DataFrame(hddm.load_csv('PD_PS.csv'))

# Define the function to estimate the regression
# lambda is a one-line function definition
reg_func = lambda args, cols: args[0] + args[1]*cols[:,0]
    
# Define the regression descriptor where we specify
reg = {'func': reg_func, # which function to use
       'args': ['a_intercept','a_slope'], # the input arguments (arbitrary)
       'covariates': 'theta', # the name of column to use for the covariate (will be the argument cols to the function above)
       'outcome': 'a' # which parameter to regress on
       }
m_reg = hddm.HDDMRegressor(data, reg, depends_on={'a_slope': 'dbs_inv', 'v': 'conf'}, group_only_nodes=['a_intercept', 'a_slope'])

# %%
# Warning, takes a long time to execute!
#m_reg.sample(20000, burn=15000)

# %%
kabuki.analyze.plot_posterior_nodes(m_reg.nodes_db.node[['a_slope(0)', 'a_slope(1)']], bins=15)

# %% [markdown]
# For more details, see http://ski.clps.brown.edu/papers/Cavanagh_DBSEEG.pdf

# %% [markdown]
# ## Posterior Predictive Checks

# %%
from hddm.utils import post_pred_check
post_pred_check(m_no_outlier)

# %% [markdown]
# ## IPython notebook foo

# %% [raw]
# Executing code in octave (or matlab)

# %%
# %load_ext octavemagic

# %%
# %%octave -s 500,500
# b = [0.292893218813452, 0.585786437626905, 0.292893218813452];
# a = [1,  0,  0.171572875253810];
# freqz(b, a, 32);

# %% [raw]
# Execute code in R

# %%
# %load_ext rmagic
import numpy
X = np.array([0,1,2,3,4])
Y = np.array([3,5,4,6,7])

# %%
# %%R -i X,Y -o XYcoef
# XYlm = lm(Y~X)
# XYcoef = coef(XYlm)
# print(summary(XYlm))
# par(mfrow=c(2,2))
# plot(XYlm)
